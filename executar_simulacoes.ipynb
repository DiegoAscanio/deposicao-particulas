# %% [markdown]
# # Executar Simulações de Deposição

# %%
# importação dos objetos
from deposicao import DeposicaoAleatoria, DeposicaoAleatoriaRelaxacaoSuperficial, DeposicaoBalistica
from rng import RNG_PCG
import numpy as np
import pdb
import time
from multiprocessing import Pool

def simular(deposicao):
    deposicao.simular(verbose = False)
    return deposicao

'''
    Descomente a forma de deposição desejada (Aleatoria, Aleatoria com Relaxação
    Superficial ou Balística) e comente as demais.
'''
#forma_deposicao = DeposicaoAleatoria
forma_deposicao = DeposicaoAleatoriaRelaxacaoSuperficial
#forma_deposicao = DeposicaoBalistica

# numero de nucleos de processamento disponiveis, no nosso caso 4
instancias_paralelas = 4

# o numero de amostras totais, multiplo dos nucleos de processamento
# disponíveis
amostras = 32 * instancias_paralelas

# tempo minimo 10^4
t_min = 10 ** 4

# conseguimos simular subestratos distintos
# recomendamos que simulem de 1 em 1 em cada
# simulação
comprimentos_subestratos = [200, 400, 800, 1600]

if forma_deposicao == DeposicaoAleatoria:
    # na deposição aleatoria, a rugosidade nunca satura, por isso, não
    # faz sentido tempo_maximo > t_min
    z = 0
    coeficiente_tempo_maximo = 0
else:
    coeficiente_tempo_maximo = 1.1
    if forma_deposicao == DeposicaoAleatoriaRelaxacaoSuperficial:
        # na deposicao aleatoria com relaxacao superficial ocorre saturacao
        # da rugosidade quando t > L**2. Neste sentido, , tempo_maximo = 
        # max(10**4, 1.1*L**2)
        z = 2
    elif forma_deposicao == DeposicaoBalistica:
        # na deposicao balistica ocorre saturacao da rugosidade quando t > L**(3/2).
        # Neste sentido, , tempo_maximo = max(10**4, 1.1*L**(3/2))
        z = 3/2

# quantidade de snapshots (ou de instantanenos da simulação da deposição) para
# armazenarmos os dados do nosso interesse: instantaneos do crescimento da in-
# face e rugosidades
janelas = 1000

t_max = lambda L, z = z, c = coeficiente_tempo_maximo, j = janelas:\
    np.int32(np.round(c * (L ** z)) - np.round(c * (L ** z)) % j)

tempo_maximo = {
    # setando tempo_maximo para cada tipo comprimento de subestrato definido em
    # comprimentos_subestratos
    L: max(t_min, t_max(L))
    for L in comprimentos_subestratos
}

dados_medios = {
    L:  {
        'interfaces': np.zeros(L),
        'tempo_maximo': tempo_maximo[L],
        'snapshots': janelas,
        'evolucao_subestratos': np.zeros((janelas ,L)),
        'rugosidades': np.zeros((janelas)),
        'amostras': amostras
    }
    for L in comprimentos_subestratos
}

# instanciando geradores de numeros aleatorios
rngs = [RNG_PCG() for i in range(instancias_paralelas)]

t_inicio = time.time()
for L in comprimentos_subestratos:
    tempo_maximo = dados_medios[L]['tempo_maximo']
    snapshots = dados_medios[L]['snapshots']
    
    # avancar o estado dos geradores de numeros aleatorios para cada instancia
    for i in range(1, instancias_paralelas):
        rngs[i].fast_forward(i * tempo_maximo)
    
    future_steps = 1
    for amostra in range(0,amostras,instancias_paralelas):
        # instancio instancias_paralelas de objetos de deposicao aleatoria
        instancias = []
        for i in range(instancias_paralelas):
            instancias.append(
                forma_deposicao(i, L, rngs[i], tempo_maximo = tempo_maximo, snapshots = snapshots )
            )
        
        begin = time.time()
        # simulacao de instancias_paralelas deposicoes
        print('L: {}, Simulacao das amostras {} a {}'.format(L, amostra + 1, amostra + instancias_paralelas))
        pool = Pool()
        deposicoes = pool.map(simular, instancias)
        pool.close()
        pool.join()
        print('Tempo Gasto: {:.2f}s'.format(time.time() - begin))
        
        # armazenar resultados
        for d in deposicoes:
            dados_medios[L]['evolucao_subestratos'] += d.altura_sitios / amostras
            dados_medios[L]['interfaces'] += d.altura_interface / amostras
            dados_medios[L]['rugosidades'] += d.rugosidade() / amostras
        
        # avancar geradores de numeros aleatorios
        for i in range(instancias_paralelas):
            rngs[i].fast_forward((i + future_steps * instancias_paralelas) * tempo_maximo)
        future_steps += 1
print('Tempo Total Gasto: {:.2f}s'.format(time.time() - t_inicio))
# Out:
# L: 200, Simulacao das amostras 1 a 4
# Tempo Gasto: 2.39s
# L: 200, Simulacao das amostras 5 a 8
# Tempo Gasto: 2.35s
# L: 200, Simulacao das amostras 9 a 12
# Tempo Gasto: 2.30s
# L: 200, Simulacao das amostras 13 a 16
# Tempo Gasto: 2.16s
# L: 200, Simulacao das amostras 17 a 20
# Tempo Gasto: 2.45s
# L: 200, Simulacao das amostras 21 a 24
# Tempo Gasto: 2.40s
# L: 200, Simulacao das amostras 25 a 28
# Tempo Gasto: 2.29s
# L: 200, Simulacao das amostras 29 a 32
# Tempo Gasto: 2.31s
# L: 200, Simulacao das amostras 33 a 36
# Tempo Gasto: 2.53s
# L: 200, Simulacao das amostras 37 a 40
# Tempo Gasto: 2.67s
# L: 200, Simulacao das amostras 41 a 44
# Tempo Gasto: 2.45s
# L: 200, Simulacao das amostras 45 a 48
# Tempo Gasto: 3.05s
# L: 200, Simulacao das amostras 49 a 52
# Tempo Gasto: 3.05s
# L: 200, Simulacao das amostras 53 a 56
# Tempo Gasto: 3.09s
# L: 200, Simulacao das amostras 57 a 60
# Tempo Gasto: 2.73s
# L: 200, Simulacao das amostras 61 a 64
# Tempo Gasto: 2.73s
# L: 200, Simulacao das amostras 65 a 68
# Tempo Gasto: 2.75s
# L: 200, Simulacao das amostras 69 a 72
# Tempo Gasto: 2.81s
# L: 200, Simulacao das amostras 73 a 76
# Tempo Gasto: 2.75s
# L: 200, Simulacao das amostras 77 a 80
# Tempo Gasto: 2.77s
# L: 200, Simulacao das amostras 81 a 84
# Tempo Gasto: 2.77s
# L: 200, Simulacao das amostras 85 a 88
# Tempo Gasto: 2.79s
# L: 200, Simulacao das amostras 89 a 92
# Tempo Gasto: 2.75s
# L: 200, Simulacao das amostras 93 a 96
# Tempo Gasto: 2.72s
# L: 200, Simulacao das amostras 97 a 100
# Tempo Gasto: 2.99s
# L: 200, Simulacao das amostras 101 a 104
# Tempo Gasto: 2.75s
# L: 200, Simulacao das amostras 105 a 108
# Tempo Gasto: 2.73s
# L: 200, Simulacao das amostras 109 a 112
# Tempo Gasto: 2.77s
# L: 200, Simulacao das amostras 113 a 116
# Tempo Gasto: 2.66s
# L: 200, Simulacao das amostras 117 a 120
# Tempo Gasto: 2.76s
# L: 200, Simulacao das amostras 121 a 124
# Tempo Gasto: 2.81s
# L: 200, Simulacao das amostras 125 a 128
# Tempo Gasto: 2.84s
# L: 400, Simulacao das amostras 1 a 4
# Tempo Gasto: 12.13s
# L: 400, Simulacao das amostras 5 a 8
# Tempo Gasto: 12.42s
# L: 400, Simulacao das amostras 9 a 12
# Tempo Gasto: 12.36s
# L: 400, Simulacao das amostras 13 a 16
# Tempo Gasto: 13.08s
# L: 400, Simulacao das amostras 17 a 20
# Tempo Gasto: 12.33s
# L: 400, Simulacao das amostras 21 a 24
# Tempo Gasto: 12.68s
# L: 400, Simulacao das amostras 25 a 28
# Tempo Gasto: 12.07s
# L: 400, Simulacao das amostras 29 a 32
# Tempo Gasto: 11.82s
# L: 400, Simulacao das amostras 33 a 36
# Tempo Gasto: 12.45s
# L: 400, Simulacao das amostras 37 a 40
# Tempo Gasto: 12.15s
# L: 400, Simulacao das amostras 41 a 44
# Tempo Gasto: 11.90s
# L: 400, Simulacao das amostras 45 a 48
# Tempo Gasto: 11.95s
# L: 400, Simulacao das amostras 49 a 52
# Tempo Gasto: 11.66s
# L: 400, Simulacao das amostras 53 a 56
# Tempo Gasto: 11.64s
# L: 400, Simulacao das amostras 57 a 60
# Tempo Gasto: 11.68s
# L: 400, Simulacao das amostras 61 a 64
# Tempo Gasto: 11.50s
# L: 400, Simulacao das amostras 65 a 68
# Tempo Gasto: 11.51s
# L: 400, Simulacao das amostras 69 a 72
# Tempo Gasto: 11.46s
# L: 400, Simulacao das amostras 73 a 76
# Tempo Gasto: 11.47s
# L: 400, Simulacao das amostras 77 a 80
# Tempo Gasto: 11.57s
# L: 400, Simulacao das amostras 81 a 84
# Tempo Gasto: 11.56s
# L: 400, Simulacao das amostras 85 a 88
# Tempo Gasto: 11.71s
# L: 400, Simulacao das amostras 89 a 92
# Tempo Gasto: 11.59s
# L: 400, Simulacao das amostras 93 a 96
# Tempo Gasto: 12.49s
# L: 400, Simulacao das amostras 97 a 100
# Tempo Gasto: 11.69s
# L: 400, Simulacao das amostras 101 a 104
# Tempo Gasto: 11.73s
# L: 400, Simulacao das amostras 105 a 108
# Tempo Gasto: 12.48s
# L: 400, Simulacao das amostras 109 a 112
# Tempo Gasto: 12.59s
# L: 400, Simulacao das amostras 113 a 116
# Tempo Gasto: 12.72s
# L: 400, Simulacao das amostras 117 a 120
# Tempo Gasto: 11.90s
# L: 400, Simulacao das amostras 121 a 124
# Tempo Gasto: 12.49s
# L: 400, Simulacao das amostras 125 a 128
# Tempo Gasto: 12.03s
# L: 800, Simulacao das amostras 1 a 4
# Tempo Gasto: 56.64s
# L: 800, Simulacao das amostras 5 a 8
# Tempo Gasto: 54.63s
# L: 800, Simulacao das amostras 9 a 12
# Tempo Gasto: 55.00s
# L: 800, Simulacao das amostras 13 a 16
# Tempo Gasto: 57.92s
# L: 800, Simulacao das amostras 17 a 20
# Tempo Gasto: 71.64s
# L: 800, Simulacao das amostras 21 a 24
# Tempo Gasto: 58.78s
# L: 800, Simulacao das amostras 25 a 28
# Tempo Gasto: 54.63s
# L: 800, Simulacao das amostras 29 a 32
# Tempo Gasto: 54.72s
# L: 800, Simulacao das amostras 33 a 36
# Tempo Gasto: 56.49s
# L: 800, Simulacao das amostras 37 a 40
# Tempo Gasto: 54.22s
# L: 800, Simulacao das amostras 41 a 44
# Tempo Gasto: 53.56s
# L: 800, Simulacao das amostras 45 a 48
# Tempo Gasto: 53.46s
# L: 800, Simulacao das amostras 49 a 52
# Tempo Gasto: 53.85s
# L: 800, Simulacao das amostras 53 a 56
# Tempo Gasto: 53.59s
# L: 800, Simulacao das amostras 57 a 60
# Tempo Gasto: 53.89s
# L: 800, Simulacao das amostras 61 a 64
# Tempo Gasto: 54.01s
# L: 800, Simulacao das amostras 65 a 68
# Tempo Gasto: 53.59s
# L: 800, Simulacao das amostras 69 a 72
# Tempo Gasto: 53.68s
# L: 800, Simulacao das amostras 73 a 76
# Tempo Gasto: 53.33s
# L: 800, Simulacao das amostras 77 a 80
# Tempo Gasto: 53.42s
# L: 800, Simulacao das amostras 81 a 84
# Tempo Gasto: 53.67s
# L: 800, Simulacao das amostras 85 a 88
# Tempo Gasto: 53.40s
# L: 800, Simulacao das amostras 89 a 92
# Tempo Gasto: 53.00s
# L: 800, Simulacao das amostras 93 a 96
# Tempo Gasto: 53.37s
# L: 800, Simulacao das amostras 97 a 100
# Tempo Gasto: 53.28s
# L: 800, Simulacao das amostras 101 a 104
# Tempo Gasto: 55.34s
# L: 800, Simulacao das amostras 105 a 108
# Tempo Gasto: 53.82s
# L: 800, Simulacao das amostras 109 a 112
# Tempo Gasto: 53.15s
# L: 800, Simulacao das amostras 113 a 116
# Tempo Gasto: 53.62s
# L: 800, Simulacao das amostras 117 a 120
# Tempo Gasto: 53.67s
# L: 800, Simulacao das amostras 121 a 124
# Tempo Gasto: 53.51s
# L: 800, Simulacao das amostras 125 a 128
# Tempo Gasto: 53.68s
# L: 1600, Simulacao das amostras 1 a 4
# Tempo Gasto: 275.36s
# L: 1600, Simulacao das amostras 5 a 8
# Tempo Gasto: 277.10s
# L: 1600, Simulacao das amostras 9 a 12
# Tempo Gasto: 275.52s
# L: 1600, Simulacao das amostras 13 a 16
# Tempo Gasto: 275.69s
# L: 1600, Simulacao das amostras 17 a 20
# Tempo Gasto: 274.97s
# L: 1600, Simulacao das amostras 21 a 24
# Tempo Gasto: 273.50s
# L: 1600, Simulacao das amostras 25 a 28
# Tempo Gasto: 274.42s
# L: 1600, Simulacao das amostras 29 a 32
# Tempo Gasto: 277.62s
# L: 1600, Simulacao das amostras 33 a 36
# Tempo Gasto: 280.40s
# L: 1600, Simulacao das amostras 37 a 40
# Tempo Gasto: 310.62s
# L: 1600, Simulacao das amostras 41 a 44
# Tempo Gasto: 355.41s
# L: 1600, Simulacao das amostras 45 a 48

# %% [markdown]
# # Salvar os Dados Para Uso Posterior

# %%
import pickle

diretorio = {
    DeposicaoAleatoria: 'DA',
    DeposicaoAleatoriaRelaxacaoSuperficial: 'DARS',
    DeposicaoBalistica: 'DB'
}

for L in comprimentos_subestratos:
    f = open('simulacoes/'+ diretorio[forma_deposicao] +'/L_{}'.format(L), 'wb')
    pickle.dump(dados_medios[L], f)
    f.close()
